# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import schemdraw
import schemdraw.elements as elm
import sympy as sp

# %%
class si :
    """
    This is a simple class that provides an easy way to access the engineering prefixes for the metric system.
    Example:
        25*si.k results in 25_000
    """
    Y = 10**24  # Yotta
    Z = 10**21  # Zetta
    E = 10**18  # Exa
    P = 10**15  # Peta
    T = 10**12  # Tera
    G = 10**9   # Giga
    M = 10**6   # Mega
    k = 10**3   # kilo

    m = 10**-3  # milli
    µ = 10**-6  # micro
    u = 10**-6  # micro ## so that we can type u instead of µ
    n = 10**-9  # nano
    p = 10**-12 # pico
    f = 10**-15 # femto
    a = 10**-18 # atto
    z = 10**-21 # zepto
    y = 10**-24 # yocto

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $\mathcal{SOH\  CAH\  TOA}$
#
# "SOH CAH TOA" is a common mnemonic used to describe the function's relationship to the sides of a triangle.
#
# $$
# \begin{align*}
# \sin(\alpha) &= \frac{\text{opposite}}{\text{hypotenuse}}\\
# \\
# \cos(\alpha) &= \frac{\text{adjacent}}{\text{hypotenuse}}\\
# \\
# \tan(\alpha) &= \frac{\text{opposite}}{\text{adjacent}}\\
# \end{align*}
# $$

# %% [markdown]
# ![power-triangle.png](attachment:power-triangle.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The load in the above figure is known to be inductive and consumes 90 kW. The ammeter reading is 260 A rms, and the voltmeter reading is 480 V rms.
# Determine the power factor of the total.

# %%
true_power = 90*si.k #Watts , Given
I = 260 #amps
V = 480 #Volts

# %% [markdown]
# $$ P = I \cdot V $$

# %%
apparent_power = I*V # Volt-Amps, RMS
apparent_power

# %% [markdown]
# $$ P_F = \cos(\theta) $$
# $$ \cos(\theta) = \frac{P_t}{P_a} $$

# %%
power_factor = true_power/apparent_power
power_factor
# Out:
# 0.7211538461538461
