# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import EngFormatter
import seaborn as sns

# %%
class si :
    """
    This is a simple class that provides an easy way to access the engineering prefixes for the metric system.
    Example:
        25*si.k results in 25_000
    """
    Y = 10**24  # Yotta
    Z = 10**21  # Zetta
    E = 10**18  # Exa
    P = 10**15  # Peta
    T = 10**12  # Tera
    G = 10**9   # Giga
    M = 10**6   # Mega
    k = 10**3   # kilo

    m = 10**-3  # milli
    µ = 10**-6  # micro
    u = 10**-6  # micro ## so that we can type u instead of µ
    n = 10**-9  # nano
    p = 10**-12 # pico
    f = 10**-15 # femto
    a = 10**-18 # atto
    z = 10**-21 # zepto
    y = 10**-24 # yocto

# %% [markdown]
# ## EET220 - 2.3 - UJT Resistances

# %%
x = [
    900*si.n,
    900*si.m,
    1.8,
    2.7,
    3.6,
    4.5,
    5.4,
    6.3,
    7.2,
    4.1,
    4.63,
    4.95
]

y= [
    -2*si.p,
    0,
    3.5*si.p,
    6.25*si.p,
    9*si.p,
    11.8*si.p,
    14.6*si.p,
    17.3*si.p,
    1.11*si.n,
    6.7*si.m,
    7.9*si.m,
    8.6*si.m,
]

plt.plot(y,x)
plt.xlabel('Current in $A$')
plt.xscale('logit')
plt.ylabel("Voltage Drop across UJT in $V$")
plt.title("Negative Resistance zone of UJT")
# Out:
# Text(0.5, 1.0, 'Negative Resistance zone of UJT')
