# %% [markdown]
# # Basic Components

# %% [markdown]
# ## Resistors

# %% [markdown]
# ### Color Codes
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)
#
# ### Impedance (Resistance)
# $$ Z = \frac{V}{I} $$
