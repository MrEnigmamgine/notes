# %%
import sympy as sp
import numpy as np

x, y = sp.symbols('x, y')

# %% [markdown]
# ### 1
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# \lim_{R \to \infty} \frac{10 \cdot R}{10 + R}
# = \lim_{R \to \infty} \frac{R \cdot 10}{R \cdot \left(\frac{10}{R} + 1\right)}
# = \lim_{R \to \infty} \frac{10}{\frac{10}{R} + 1}
# = \frac{10}{0 + 1}
# = \boxed{10}
# $$

# %% [markdown]
# ### 2
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
550-220*2.5
# Out:
# 0.0

# %%
expr = 90+360*x-120*x**2
expr.diff().subs(x,1.5)
# Out:
# 0

# %% [markdown]
# ### 11
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Differentiate using the quotient rule
# Displays in format accepted by Pearson MyLab
def quotient_rule(expr, wrt=x):
    # Extract the numerator and denominator
    hi, lo = expr.as_numer_denom()
    # Find their derivatives individually
    d_hi = hi.diff(wrt)
    d_lo = lo.diff(wrt)
    # Apply the quotient rule formula
    top =  lo*d_hi - hi*d_lo # I named the variables to mimic the mnemonic
    bottom = lo*lo 
    return sp.simplify(top.expand())/bottom

# Demo
expr = (7*x**2+6)/(x**2+3)
display(expr)
quotient_rule(expr, x)
# Out:
# (7*x**2 + 6)/(x**2 + 3)
# 30*x/(x**2 + 3)**2

# %% [markdown]
# ### 6
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
expr = (4*x**3+5)**sp.Rational(3,2)
expr.diff()
# Out:
# 18*x**2*sqrt(4*x**3 + 5)

# %% [markdown]
# ### 2
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def implicit_diff(expr, wrt=x, solve_for=y, return_dict=False):
    # Treat every variable as a function of a single variable (which is implied)
    funcs = {}
    syms = {}
    for var in expr.free_symbols:
        func = sp.Function(str(var))(wrt)
        funcs[var] = func
        syms[func] = var
    expr_funcs = expr.subs(funcs)
    # Differentiate the entire thing with respect to your variable
    diff_expr_funcs = expr_funcs.diff(wrt)
    # Solve for the derivative that you want
    solution = sp.solve(diff_expr_funcs, funcs[solve_for].diff())
    
    if return_dict:
        output = {
            'solution': solution,
            'functions': funcs,
            'symbols': syms,
        }
        return output
    else:
        return solution
    
# Demo
expr = 4*x**2 - 3*y**2 -3
for sol in implicit_diff(expr, x, y):
    display(sol.simplify())

## Accepted answer = 2x/3y
# Out:
# 4*x(x)*Derivative(x(x), x)/(3*y(x))

# %% [markdown]
# ### 1
# ![image.png](attachment:image.png)

# %%
t = sp.symbols('t')
expr = 5*sp.tan(4*t)**9
expr.diff().simplify()
# Out:
# 180*tan(4*t)**8/cos(4*t)**2

# %% [markdown]
# ### 10
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Where is slope 0 and second derivative negative?
t = sp.symbols('t')
expr = sp.ln(t+2) -0.2*t
sp.solve(expr.diff().factor(), t)
# Out:
# [3.00000000000000]

# %%
sp.plot(expr, xlim=(0,5), ylim=(-1, 5))
sp.plot(expr.diff(), xlim=(0,5), ylim=(-.1, .1))

# %% [markdown]
# ### 9
# ![image.png](attachment:image.png)

# %%
# in head, 10?
expr = 2*t**2 +8*t
expr.diff(t, 2)
# Out:
# 4

# %% [markdown]
# ### 10
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# x**10 + 9/8x**8 ?
expr = 4*x**3 - 3/x**3
display(expr)
## Don't forget C!
C = sp.symbols('C')
expr.integrate() + C
# Out:
# 4*x**3 - 3/x**3
# C + x**4 + 3/(2*x**2)

# %% [markdown]
# ### 3
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
expr = 2*x*(5-x**2)**3
a, b = -3, -2
wrt = x

expr.integrate((wrt, a, b))
# Out:
# 255/4

# %% [markdown]
# ### 7
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
expr = sp.cos(8*x)/sp.csc(8*x)
a, b = 0, sp.pi/32
wrt = x

expr.integrate((wrt, a, b))
# Out:
# 1/32

# %% [markdown]
# ### 5
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
expr = 1/(2+3*x)
display(expr)
## Don't forget C!
C = sp.symbols('C')
expr.integrate() + C  ## sympy treats \ln as \log
# Out:
# 1/(3*x + 2)
# C + log(3*x + 2)/3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 8
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
expr = sp.E**sp.sqrt(y)/sp.sqrt(y)
a, b = 1,4
wrt = y

expr.integrate((wrt, a, b)).evalf()
# Out:
# 9.34154854094321

# %% [markdown]
# ## 9
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
expr1 = 25-x**2
expr2 = 0
a, b = -4, 3

sp.integrate(expr1 - expr2, (x, a, b))
# Out:
# 434/3

# %%
sp.plot(expr1, expr2)
