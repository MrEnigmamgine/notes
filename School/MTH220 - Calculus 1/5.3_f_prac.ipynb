# %%
import sympy as sp
import numpy as np

x, y = sp.symbols('x, y')

# %% [markdown]
# ### 1
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# \lim_{R \to \infty} \frac{10 \cdot R}{10 + R}
# = \lim_{R \to \infty} \frac{R \cdot 10}{R \cdot \left(\frac{10}{R} + 1\right)}
# = \lim_{R \to \infty} \frac{10}{\frac{10}{R} + 1}
# = \frac{10}{0 + 1}
# = \boxed{10}
# $$

# %% [markdown]
# ### 2
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3
# ![image.png](attachment:image.png)

# %%
550-220*2.5
# Out:
# 0.0

# %%
expr = 120+550*x-110*x**2
expr.diff().subs(x,2.5)
# Out:
# 0

# %% [markdown]
# ### 4
# ![image.png](attachment:image.png)

# %%
# Differentiate using the quotient rule
# Displays in format accepted by Pearson MyLab
def quotient_rule(expr, wrt=x):
    # Extract the numerator and denominator
    hi, lo = expr.as_numer_denom()
    # Find their derivatives individually
    d_hi = hi.diff(wrt)
    d_lo = lo.diff(wrt)
    # Apply the quotient rule formula
    top =  lo*d_hi - hi*d_lo # I named the variables to mimic the mnemonic
    bottom = lo*lo 
    return sp.simplify(top.expand())/bottom

# Demo
expr = (6*x**2+5)/(x**2+4)
quotient_rule(expr, x)
# Out:
# 38*x/(x**2 + 4)**2

# %% [markdown]
# ### 5
# ![image.png](attachment:image.png)

# %%
expr = (4*x**3+7)**sp.Rational(3,2)
expr.diff()
# Out:
# 18*x**2*sqrt(4*x**3 + 7)

# %% [markdown]
# ### 6
# ![image.png](attachment:image.png)

# %%
def implicit_diff(expr, wrt=x, solve_for=y, return_dict=False):
    # Treat every variable as a function of a single variable (which is implied)
    funcs = {}
    syms = {}
    for var in expr.free_symbols:
        func = sp.Function(str(var))(wrt)
        funcs[var] = func
        syms[func] = var
    expr_funcs = expr.subs(funcs)
    # Differentiate the entire thing with respect to your variable
    diff_expr_funcs = expr_funcs.diff(wrt)
    # Solve for the derivative that you want
    solution = sp.solve(diff_expr_funcs, funcs[solve_for].diff())
    
    if return_dict:
        output = {
            'solution': solution,
            'functions': funcs,
            'symbols': syms,
        }
        return output
    else:
        return solution
    
# Demo
expr = 2*x**2 -3*y**2 -2
for sol in implicit_diff(expr, x, y):
    display(sol.simplify())

## Accepted answer = 2x/3y
# Out:
# 2*x(x)*Derivative(x(x), x)/(3*y(x))

# %% [markdown]
# ### 7
# ![image.png](attachment:image.png)

# %%
expr = 9*sp.tan(4*x)**7
expr.diff().simplify()
# Out:
# 252*tan(4*x)**6/cos(4*x)**2

# %% [markdown]
# ### 8
# ![image.png](attachment:image.png)

# %%
## Where is slope 0 and second derivative negative?
t = sp.symbols('t')
expr = sp.ln(t+7) -0.125*t
sp.solve(expr.diff().factor(), t)
# Out:
# [1.00000000000000]

# %%
sp.plot(expr, xlim=(0,5), ylim=(-1, 5))
sp.plot(expr.diff(), xlim=(0,5), ylim=(-.1, .1))

# %% [markdown]
# ### 9
# ![image.png](attachment:image.png)

# %%
# in head, 10?
expr = 5*t**2 +10*t
expr.diff(t, 2)
# Out:
# 10

# %% [markdown]
# ### 10
# ![image.png](attachment:image.png)

# %%
# x**10 + 9/8x**8 ?
expr = 10*x**9 - 9/x**9
expr.integrate()
## Don't forget C!
C = sp.symbols('C')
expr.integrate() + C
# Out:
# C + x**10 + 9/(8*x**8)

# %% [markdown]
# ### 11
# ![image.png](attachment:image.png)

# %%
expr = 2*x*(5-x**2)**3
a, b = -3, -2
wrt = x

expr.integrate((wrt, a, b))
# Out:
# 255/4

# %% [markdown]
# ### 12
# ![image.png](attachment:image.png)

# %%
expr = sp.cos(7*x)/sp.csc(7*x)
a, b = 0, sp.pi/42
wrt = x

expr.integrate((wrt, a, b))
# Out:
# 1/56

# %% [markdown]
# ### 13
# ![image.png](attachment:image.png)

# %%
expr = 1/(6+7*x)
## Don't forget C!
C = sp.symbols('C')
expr.integrate() + C  ## sympy treats \ln as \log
# Out:
# C + log(7*x + 6)/7

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 14
# ![image.png](attachment:image.png)

# %%
expr = sp.E**sp.sqrt(y)/sp.sqrt(y)
a, b = 4, 16
wrt = y

expr.integrate((wrt, a, b)).evalf()
# Out:
# 94.4181878684272

# %% [markdown]
# ## 15
# ![image.png](attachment:image.png)

# %%
expr1 = 16-x**2
expr2 = 0
a, b = -2, 3

sp.integrate(expr1 - expr2, (x, a, b))
# Out:
# 205/3

# %%
sp.plot(expr1, expr2)
