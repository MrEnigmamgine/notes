# %%
import numpy as np
import sympy as sp
import math

# %%
k_rmp_rad = 2*math.pi/60
k_mph_fps = 60/88

# %%
#Given

#Assumed

#Unit Conversions

#Unknown

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Formulas:
#
# $ U = Fs $

# %%
#Given
s = 7 #ft
Y = 89 #lb
Z = 51
Z_slope = math.radians(-35)

#Assumed
Y_slope = math.atan2(3,4)

#Unkown
U = __

# %%
#Sum the horizontal components of each force
Fx = math.cos(Y_slope)*Y
Fx = Fx + math.cos(Z_slope)*Z
Fx #lb
# Out:
# 112.9767542587386

# %%
#Solve for work
U = Fx*s
U #ft-lb
# Out:
# 790.8372798111702

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Formula:
#
# $ E_K = \frac{1}{2} m v^2 $
# $ F = ma $

# %%
# Given
W = 42_000 #N
v = 23 #m/s

# Assumed
g = 9.81 #m/s/s

# Unkown
KE = __

# %%
m = W/g
KE = 1/2*m * v**2
KE #J
# Out:
# 1132415.9021406726

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Formula:
#
# $ v_f^2 = v_i^2 + 2as $

# %%
# Given
vi = 21 #m/s

# Assumed
g = 9.81 #m/s/s
vf = 0

# Find
s = __

# %%
s = (vf**2 - vi**2)/(2*-g)
s #m
# Out:
# 22.477064220183486

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Formula:
#
# $ E_K = \frac{1}{2} I \omega^2 $

# %%
# Given
I = 0.44 #kg-m-m
KE = 25 #J

# Unit Conversions
k_rmp_rad = 2*math.pi/60

# Find
omega = __
rpm = __

# %%
omega = math.sqrt(KE/(1/2*I))
rpm = omega/k_rmp_rad
rpm
# Out:
# 101.7958436361855

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Formula:
#
# $ U = \Tau \cdot \theta $

# %%
# Given
Tau = 17 #N-m
theta = math.pi

# Find
U = __

# %%
U = Tau * theta
U #N-m or J
# Out:
# 53.40707511102649
